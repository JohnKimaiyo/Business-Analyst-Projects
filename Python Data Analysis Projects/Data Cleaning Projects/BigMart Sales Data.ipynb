# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\Big Mart Sales.csv")
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP         Sales Budgeted Sales OutletID  Date OutletSize  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP         Sales Budgeted Sales OutletID  Date OutletSize  \
# ...

# %%
df["OutletSize"] = df["OutletSize"].str.replace('Medium','M')

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP         Sales Budgeted Sales OutletID  Date OutletSize  \
# ...

# %%
df["OutletSize"] = df["OutletSize"].str.replace('Small','S')

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP         Sales Budgeted Sales OutletID  Date OutletSize  \
# ...

# %%
df["OutletSize"] = df["OutletSize"].str.replace('NaN','')
