# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Data Analysis Porfolio Projects\Python Data Analysis Projects\Data Cleaning Projects\Customer Call List\MTA\MTA_NYCT_Paratransit_Call_Center_Performance__Beginning_2016.csv")
df
# Out:
#           Month        Call Type  Number of Calls Received  \
# 0    09/01/2016     Reservations                    365140
# 1    09/01/2016  Transit Control                    284798
# 2    10/01/2016     Reservations                    364498
# 3    10/01/2016  Transit Control                    265864
# 4    11/01/2016     Reservations                    363190
# ..          ...              ...                       ...
# 167  08/01/2023  Transit Control                    264236
# 168  09/01/2023     Reservations                    465731
# 169  09/01/2023  Transit Control                    304932
# 170  10/01/2023     Reservations                    492853
# 171  10/01/2023  Transit Control                    291869
#
#      Number of Calls Picked Up Calls Answered  Average Answer Speed
# 0                       352564            97%                    44
# 1                       272874            96%                    26
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#           Month        Call Type  Number of Calls Received  \
# 0    09/01/2016     Reservations                    365140
# 1    09/01/2016  Transit Control                    284798
# 2    10/01/2016     Reservations                    364498
# 3    10/01/2016  Transit Control                    265864
# 4    11/01/2016     Reservations                    363190
# ..          ...              ...                       ...
# 167  08/01/2023  Transit Control                    264236
# 168  09/01/2023     Reservations                    465731
# 169  09/01/2023  Transit Control                    304932
# 170  10/01/2023     Reservations                    492853
# 171  10/01/2023  Transit Control                    291869
#
#      Number of Calls Picked Up Calls Answered  Average Answer Speed
# 0                       352564            97%                    44
# 1                       272874            96%                    26
# ...

# %%
df=df.fillna('')
df
# Out:
#           Month        Call Type  Number of Calls Received  \
# 0    09/01/2016     Reservations                    365140
# 1    09/01/2016  Transit Control                    284798
# 2    10/01/2016     Reservations                    364498
# 3    10/01/2016  Transit Control                    265864
# 4    11/01/2016     Reservations                    363190
# ..          ...              ...                       ...
# 167  08/01/2023  Transit Control                    264236
# 168  09/01/2023     Reservations                    465731
# 169  09/01/2023  Transit Control                    304932
# 170  10/01/2023     Reservations                    492853
# 171  10/01/2023  Transit Control                    291869
#
#      Number of Calls Picked Up Calls Answered  Average Answer Speed
# 0                       352564            97%                    44
# 1                       272874            96%                    26
# ...
