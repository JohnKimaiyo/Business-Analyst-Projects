# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Data Analysis Porfolio Projects\Python Data Analysis Projects\Data Cleaning Projects\Customer Call List\DOHMH Call Center Summary\DOHMH_Call_Center_Summary.csv")
df
# Out:
#                Metric  TotalNoOfCalls AvgSpeedOfAnswer  \
# 0    Dog License Unit             254               76
# 1           Providers             155               86
# 2                 STD            5885               85
# 3       Vital Records            7999               71
# 4    Dog License Unit             189          0:00:22
# ..                ...             ...              ...
# 199     Vital Records            5991          0:05:08
# 200  Dog License Unit             345          0:00:23
# 201         Providers             384          0:00:21
# 202               STD             961          0:00:35
# 203     Vital Records            5761          0:01:45
#
#      CallPctAnsweredWi30Secs  Month  Year
# 0                       0.95      3  2023
# 1                       0.94      3  2023
# 2                       0.36      3  2023
# 3                       0.87      3  2023
# 4                       0.96      2  2023
# ..                       ...    ...   ...
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                Metric  TotalNoOfCalls AvgSpeedOfAnswer  \
# 0    Dog License Unit             254               76
# 1           Providers             155               86
# 2                 STD            5885               85
# 3       Vital Records            7999               71
# 4    Dog License Unit             189          0:00:22
# ..                ...             ...              ...
# 199     Vital Records            5991          0:05:08
# 200  Dog License Unit             345          0:00:23
# 201         Providers             384          0:00:21
# 202               STD             961          0:00:35
# 203     Vital Records            5761          0:01:45
#
#      CallPctAnsweredWi30Secs  Month  Year
# 0                       0.95      3  2023
# 1                       0.94      3  2023
# 2                       0.36      3  2023
# 3                       0.87      3  2023
# 4                       0.96      2  2023
# ..                       ...    ...   ...
# ...

# %%
df=df.fillna('')
df
# Out:
#                Metric  TotalNoOfCalls AvgSpeedOfAnswer  \
# 0    Dog License Unit             254               76
# 1           Providers             155               86
# 2                 STD            5885               85
# 3       Vital Records            7999               71
# 4    Dog License Unit             189          0:00:22
# ..                ...             ...              ...
# 199     Vital Records            5991          0:05:08
# 200  Dog License Unit             345          0:00:23
# 201         Providers             384          0:00:21
# 202               STD             961          0:00:35
# 203     Vital Records            5761          0:01:45
#
#      CallPctAnsweredWi30Secs  Month  Year
# 0                       0.95      3  2023
# 1                       0.94      3  2023
# 2                       0.36      3  2023
# 3                       0.87      3  2023
# 4                       0.96      2  2023
# ..                       ...    ...   ...
# ...
