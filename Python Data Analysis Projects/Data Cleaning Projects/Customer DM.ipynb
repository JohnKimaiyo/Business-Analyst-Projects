# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\Customer DM.csv")

# %%
df
# Out:
#        CustomerKey First Name Last Name          Full Name  Gender  \
# 0            11000        Jon      Yang           Jon Yang    Male
# 1            11001     Eugene     Huang       Eugene Huang    Male
# 2            11002      Ruben    Torres       Ruben Torres    Male
# 3            11003    Christy       Zhu        Christy Zhu  Female
# 4            11004  Elizabeth   Johnson  Elizabeth Johnson  Female
# ...            ...        ...       ...                ...     ...
# 18479        29479      Tommy      Tang         Tommy Tang    Male
# 18480        29480       Nina      Raji          Nina Raji  Female
# 18481        29481       Ivan      Suri          Ivan Suri    Male
# 18482        29482    Clayton     Zhang      Clayton Zhang    Male
# 18483        29483      Jésus   Navarro      Jésus Navarro    Male
#
#       DateFirstPurchase     Customer City
# 0            2020-01-19       Rockhampton
# 1            2020-01-15           Seaford
# 2            2020-01-07            Hobart
# 3            2019-12-29        North Ryde
# 4            2020-01-23        Wollongong
# ...                 ...               ...
# 18479        2021-09-04        Versailles
# 18480        2022-07-17            London
# 18481        2020-08-13               Hof
# 18482        2021-09-18        Saint Ouen
# 18483        2021-09-09  Paris La Defense
#
# [18484 rows x 7 columns]

# %%
df["Gender"] = df["Gender"].str.replace('Male','M')
df["Gender"] = df["Gender"].str.replace('Female	','F')
df
# Out:
#        CustomerKey First Name Last Name          Full Name  Gender  \
# 0            11000        Jon      Yang           Jon Yang       M
# 1            11001     Eugene     Huang       Eugene Huang       M
# 2            11002      Ruben    Torres       Ruben Torres       M
# 3            11003    Christy       Zhu        Christy Zhu  Female
# 4            11004  Elizabeth   Johnson  Elizabeth Johnson  Female
# ...            ...        ...       ...                ...     ...
# 18479        29479      Tommy      Tang         Tommy Tang       M
# 18480        29480       Nina      Raji          Nina Raji  Female
# 18481        29481       Ivan      Suri          Ivan Suri       M
# 18482        29482    Clayton     Zhang      Clayton Zhang       M
# 18483        29483      Jésus   Navarro      Jésus Navarro       M
#
#       DateFirstPurchase     Customer City
# 0            2020-01-19       Rockhampton
# 1            2020-01-15           Seaford
# 2            2020-01-07            Hobart
# 3            2019-12-29        North Ryde
# 4            2020-01-23        Wollongong
# ...                 ...               ...
# 18479        2021-09-04        Versailles
# 18480        2022-07-17            London
# 18481        2020-08-13               Hof
# 18482        2021-09-18        Saint Ouen
# 18483        2021-09-09  Paris La Defense
#
# [18484 rows x 7 columns]

# %%
df["Gender"] = df["Gender"].str.replace('Female','F')

# %%
df
# Out:
#        CustomerKey First Name Last Name          Full Name Gender  \
# 0            11000        Jon      Yang           Jon Yang      M
# 1            11001     Eugene     Huang       Eugene Huang      M
# 2            11002      Ruben    Torres       Ruben Torres      M
# 3            11003    Christy       Zhu        Christy Zhu      F
# 4            11004  Elizabeth   Johnson  Elizabeth Johnson      F
# ...            ...        ...       ...                ...    ...
# 18479        29479      Tommy      Tang         Tommy Tang      M
# 18480        29480       Nina      Raji          Nina Raji      F
# 18481        29481       Ivan      Suri          Ivan Suri      M
# 18482        29482    Clayton     Zhang      Clayton Zhang      M
# 18483        29483      Jésus   Navarro      Jésus Navarro      M
#
#       DateFirstPurchase     Customer City
# 0            2020-01-19       Rockhampton
# 1            2020-01-15           Seaford
# 2            2020-01-07            Hobart
# 3            2019-12-29        North Ryde
# 4            2020-01-23        Wollongong
# ...                 ...               ...
# 18479        2021-09-04        Versailles
# 18480        2022-07-17            London
# 18481        2020-08-13               Hof
# 18482        2021-09-18        Saint Ouen
# 18483        2021-09-09  Paris La Defense
#
# [18484 rows x 7 columns]
