# %% [markdown]
# Internet Sales Adventure Wokrs Dataset
#
# Data Exploration & Cleaning
#
# The first part of any data analysis or predictive modeling task is an initial exploration of the data. Even if you collected the data yourself and you already have a list of questions in mind that you want to answer, it is important to explore the data before doing any serious analysis, since oddities in the data can cause bugs and muddle your results. Before exploring deeper questions, you have to answer many simpler ones about the form and quality of data. That said, it is important to go into your initial data exploration with a big picture question in mind since the goal of your analysis should inform how you prepare the data.

# %%
# Load in some packages
import calendar
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# lets load the dataset
internet_sales_df  = pd.read_csv(r"C:\Users\jki\Downloads\1 Adventure Wokrs\clean data\Internet Sales.csv")
internet_sales_df
# Out:
#      ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0           310      20101229    20110110     20110105        21768
# 1           346      20101229    20110110     20110105        28389
# 2           346      20101229    20110110     20110105        25863
# 3           336      20101229    20110110     20110105        14501
# 4           346      20101229    20110110     20110105        11003
# ..          ...           ...         ...          ...          ...
# 995         311      20110628    20110710     20110705        18332
# 996         348      20110628    20110710     20110705        11358
# 997         350      20110628    20110710     20110705        11447
# 998         310      20110628    20110710     20110705        13807
# 999         344      20110629    20110711     20110706        29475
#
#      PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0               1           19                  6          SO43697
# ...

# %%
# lets check for missing values
missing_values = internet_sales_df.isna().sum()
print(missing_values)
# Out:
# ProductKey                  0
# OrderDateKey                0
# DueDateKey                  0
# ShipDateKey                 0
# CustomerKey                 0
# PromotionKey                0
# CurrencyKey                 0
# SalesTerritoryKey           0
# SalesOrderNumber            0
# SalesOrderLineNumber        0
# RevisionNumber              0
# OrderQuantity               0
# UnitPrice                   0
# ExtendedAmount              0
# UnitPriceDiscountPct        0
# DiscountAmount              0
# ProductStandardCost         0
# TotalProductCost            0
# SalesAmount                 0
# TaxAmt                      0
# Freight                     0
# CarrierTrackingNumber    1000
# CustomerPONumber         1000
# OrderDate                   0
# DueDate                     0
# ShipDate                    0
# dtype: int64

# %%
# let get ride of empty cells 
internet_sales_df.dropna(subset=['CarrierTrackingNumber'],inplace = True)
internet_sales_df.dropna(subset=['CustomerPONumber'],inplace = True)

# lets check for missing values
missing_values = internet_sales_df.isna().sum()
print(missing_values)
# Out:
# ProductKey               0.0
# OrderDateKey             0.0
# DueDateKey               0.0
# ShipDateKey              0.0
# CustomerKey              0.0
# PromotionKey             0.0
# CurrencyKey              0.0
# SalesTerritoryKey        0.0
# SalesOrderNumber         0.0
# SalesOrderLineNumber     0.0
# RevisionNumber           0.0
# OrderQuantity            0.0
# UnitPrice                0.0
# ExtendedAmount           0.0
# UnitPriceDiscountPct     0.0
# DiscountAmount           0.0
# ProductStandardCost      0.0
# TotalProductCost         0.0
# SalesAmount              0.0
# TaxAmt                   0.0
# Freight                  0.0
# CarrierTrackingNumber    0.0
# CustomerPONumber         0.0
# OrderDate                0.0
# DueDate                  0.0
# ShipDate                 0.0
# dtype: float64

# %%
# lets have a look at the datatypes
internet_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             1000 non-null   int64
#  1   OrderDateKey           1000 non-null   int64
#  2   DueDateKey             1000 non-null   int64
#  3   ShipDateKey            1000 non-null   int64
#  4   CustomerKey            1000 non-null   int64
#  5   PromotionKey           1000 non-null   int64
#  6   CurrencyKey            1000 non-null   int64
#  7   SalesTerritoryKey      1000 non-null   int64
#  8   SalesOrderNumber       1000 non-null   object
#  9   SalesOrderLineNumber   1000 non-null   int64
#  10  RevisionNumber         1000 non-null   int64
#  11  OrderQuantity          1000 non-null   int64
#  12  UnitPrice              1000 non-null   int64
#  13  ExtendedAmount         1000 non-null   int64
#  14  UnitPriceDiscountPct   1000 non-null   int64
# ...

# %%
# lets chage the order date data type
internet_sales_df['OrderDate'] = pd.to_datetime(internet_sales_df['OrderDate'])
internet_sales_df['OrderDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: OrderDate
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
# let remove unwanted columns
internet_sales_df.describe()
# Out:
#         ProductKey  OrderDateKey    DueDateKey   ShipDateKey   CustomerKey  \
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03   1000.000000
# mean    320.242000  2.011026e+07  2.011042e+07  2.011041e+07  20014.305000
# std      14.154073  1.090393e+03  1.788910e+02  1.780867e+02   6366.181603
# min     310.000000  2.010123e+07  2.011011e+07  2.011010e+07  11000.000000
# 25%     311.000000  2.011022e+07  2.011030e+07  2.011023e+07  14576.750000
# 50%     313.000000  2.011041e+07  2.011042e+07  2.011042e+07  18221.000000
# 75%     328.000000  2.011052e+07  2.011061e+07  2.011060e+07  27671.500000
# max     351.000000  2.011063e+07  2.011071e+07  2.011071e+07  29475.000000
#
#        PromotionKey  CurrencyKey  SalesTerritoryKey  SalesOrderLineNumber  \
# count        1000.0  1000.000000        1000.000000                1000.0
# mean            1.0    50.419000           6.716000                   1.0
# ...

# %%
# Lets remove unwnted columns
internet_sales_df = internet_sales_df.drop(columns=['gender'])
# Out:
# Empty DataFrame
# Columns: [ProductKey, OrderDateKey, DueDateKey, ShipDateKey, CustomerKey, PromotionKey, CurrencyKey, SalesTerritoryKey, SalesOrderNumber, SalesOrderLineNumber, RevisionNumber, OrderQuantity, UnitPrice, ExtendedAmount, UnitPriceDiscountPct, DiscountAmount, ProductStandardCost, TotalProductCost, SalesAmount, TaxAmt, Freight, CarrierTrackingNumber, CustomerPONumber, OrderDate, DueDate, ShipDate]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [ProductKey, OrderDateKey, DueDateKey, ShipDateKey, CustomerKey, PromotionKey, CurrencyKey, SalesTerritoryKey, SalesOrderNumber, SalesOrderLineNumber, RevisionNumber, OrderQuantity, UnitPrice, ExtendedAmount, UnitPriceDiscountPct, DiscountAmount, ProductStandardCost, TotalProductCost, SalesAmount, TaxAmt, Freight, CarrierTrackingNumber, CustomerPONumber, OrderDate, DueDate, ShipDate]
# Index: []
#
# [0 rows x 26 columns]
