# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\Amazon Sale Report.csv")
# Out:
# C:\Users\jki\AppData\Local\Temp\ipykernel_2068\252883522.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\Amazon Sale Report.csv")

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df[df["Amount"]<=1000]
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128969  128969  404-3802633-7250760  05-31-22                     Cancelled
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
specific_Category= ["Set","kurta"]
df[df['Category'].isin(specific_Category)]
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 5            5  404-1490984-4578765  04-30-22                       Shipped
# 6            6  408-5748499-6859555  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128969  128969  404-3802633-7250760  05-31-22                     Cancelled
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df2 = df.set_index('Status')
df2
# Out:
#                                index             Order ID      Date  \
# Status
# Cancelled                          0  405-8078784-5731545  04-30-22
# Shipped - Delivered to Buyer       1  171-9198151-1101146  04-30-22
# Shipped                            2  404-0687676-7273146  04-30-22
# Cancelled                          3  403-9615377-8133951  04-30-22
# Shipped                            4  407-1069790-7240320  04-30-22
# ...                              ...                  ...       ...
# Shipped                       128970  406-6001380-7673107  05-31-22
# Shipped                       128971  402-9551604-7544318  05-31-22
# Shipped                       128972  407-9547469-3152358  05-31-22
# Shipped                       128973  402-6184140-0545956  05-31-22
# Shipped                       128974  408-7436540-8728312  05-31-22
#
#                              Fulfilment Sales Channel  ship-service-level  \
# Status
# ...

# %%
df2.filter(items = ["Fulfilment","Sales Channel"," Amount","ship-city"])
# Out:
#                              Fulfilment    ship-city
# Status
# Cancelled                      Merchant       MUMBAI
# Shipped - Delivered to Buyer   Merchant    BENGALURU
# Shipped                          Amazon  NAVI MUMBAI
# Cancelled                      Merchant   PUDUCHERRY
# Shipped                          Amazon      CHENNAI
# ...                                 ...          ...
# Shipped                          Amazon    HYDERABAD
# Shipped                          Amazon     GURUGRAM
# Shipped                          Amazon    HYDERABAD
# Shipped                          Amazon        Halol
# Shipped                          Amazon       Raipur
#
# [128975 rows x 2 columns]

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df[df["Amount"]<=1000].sort_values(by="Amount")
# Out:
#          index             Order ID      Date                        Status  \
# 15617    15617  408-0334562-3573140  04-21-22                       Shipped
# 34003    34003  408-6957110-7917911  04-10-22                       Shipped
# 48046    48046  408-6509818-6868338  04-01-22                       Shipped
# 9398      9398  408-6157116-6186727  04-24-22                       Shipped
# 4185      4185  408-9362682-0529956  04-28-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 17402    17402  407-6182670-8968301  04-20-22  Shipped - Delivered to Buyer
# 91408    91408  407-2910865-3609942  06-29-22                       Pending
# 108154  108154  171-1946102-8706726  06-15-22                       Shipped
# 114133  114133  403-6195733-3141960  06-11-22                       Shipped
# 44976    44976  405-8949995-1705116  04-03-22                     Cancelled
#
# ...
