# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\Car_sales.csv")

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.plot(title ='Sales data by Manufacturer', xlabel = 'Fuel_capacity', ylabel = 'Sales_in_thousands')
# Out:
# C:\Users\jki\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:807: UserWarning: The label '__year_resale_value' of <matplotlib.lines.Line2D object at 0x00000240E4750110> starts with '_'. It is thus excluded from the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <Axes: title={'center': 'Sales data by Manufacturer'}, xlabel='Fuel_capacity', ylabel='Sales_in_thousands'>

# %%
df.plot(kind='bar', stacked = True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: >

# %%
df.plot.hist(bins=5)
# Out:
# C:\Users\jki\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:807: UserWarning: The label '__year_resale_value' of <matplotlib.patches.Rectangle object at 0x00000240E46FFF50> starts with '_'. It is thus excluded from the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <Axes: ylabel='Frequency'>

# %%
df.plot.area(figsize = (10,5))
# Out:
# C:\Users\jki\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:807: UserWarning: The label '__year_resale_value' of <matplotlib.collections.PolyCollection object at 0x00000240ECE4B950> starts with '_'. It is thus excluded from the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <Axes: >

# %%
df.plot.pie(y="Sales_in_thousands")
# Out:
# <Axes: ylabel='Sales_in_thousands'>
