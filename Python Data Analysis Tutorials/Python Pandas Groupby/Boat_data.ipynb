# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\boat_data.csv")

# %%
df
# Out:
#           Price            Boat Type           Manufacturer  \
# 0      CHF 3337          Motor Yacht   Rigiflex power boats
# 1      EUR 3490  Center console boat      Terhi power boats
# 2      CHF 3770           Sport Boat     Marine power boats
# 3     DKK 25900           Sport Boat     Pioner power boats
# 4      EUR 3399         Fishing Boat     Linder power boats
# ...         ...                  ...                    ...
# 9883   CHF 4900           Sport Boat    Sea Ray power boats
# 9884   EUR 4516           Sport Boat                    NaN
# 9885   EUR 4499           Sport Boat  BlueCraft power boats
# 9886   EUR 4300         Pontoon Boat      Whaly power boats
# 9887   CHF 3780         Fishing Boat    DarekCo power boats
#
#                               Type  Year Built  Length  Width       Material  \
# 0              new boat from stock        2017    4.00   1.90            NaN
# 1              new boat from stock        2020    4.00   1.50  Thermoplastic
# ...

# %%
group_by_frame = df.groupby('Boat Type')

# %%
group_by_frame.mean()
# Out:
# C:\Users\jki\AppData\Local\Temp\ipykernel_8480\4024548864.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_frame.mean()
#                                           Year Built     Length     Width  \
# Boat Type
# Bowrider                                 1802.229236   6.504033  2.432274
# Bowrider,Cabin Boat,Deck Boat            2016.000000   8.300000  2.960000
# Bowrider,Center console boat,Sport Boat  2018.000000   6.810000  2.360000
# Bowrider,Classic                         1971.000000   5.790000  2.200000
# Bowrider,Deck Boat,Water ski             1995.000000   6.140000  2.470000
# ...                                              ...        ...       ...
# Trawler                                  1939.036819  13.095523  3.888612
# ...

# %%
df.groupby('Boat Type').count()
# Out:
#                                          Price  Manufacturer  Type  \
# Boat Type
# Bowrider                                   301           295   300
# Bowrider,Cabin Boat,Deck Boat                1             1     1
# Bowrider,Center console boat,Sport Boat      1             1     1
# Bowrider,Classic                             1             1     1
# Bowrider,Deck Boat,Water ski                 1             1     1
# ...                                        ...           ...   ...
# Trawler                                    679           379   679
# Wakeboard/Wakesurf                          58            58    58
# Wakeboard/Wakesurf,Water ski                 2             2     2
# Water ski                                   10             9    10
# Working Boat                                44            17    44
#
#                                          Year Built  Length  Width  Material  \
# Boat Type
# ...

# %%
df.groupby('Boat Type').max()
# Out:
# C:\Users\jki\AppData\Local\Temp\ipykernel_8480\2268331441.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Boat Type').max()
#                                              Price  Year Built  Length  Width  \
# Boat Type
# Bowrider                                  Â£ 45950        2021   11.60   7.55
# Bowrider,Cabin Boat,Deck Boat            EUR 88000        2016    8.30   2.96
# Bowrider,Center console boat,Sport Boat  EUR 27000        2018    6.81   2.36
# Bowrider,Classic                         EUR 11000        1971    5.79   2.20
# Bowrider,Deck Boat,Water ski             CHF 14950        1995    6.14   2.47
# ...                                            ...         ...     ...    ...
# Trawler                                  Â£ 600000        2020   46.40   7.47
# ...

# %%
df.groupby('Boat Type').sum()
# Out:
# C:\Users\jki\AppData\Local\Temp\ipykernel_8480\190933238.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Boat Type').sum()
#                                          Year Built   Length    Width  \
# Boat Type
# Bowrider                                     542471  1951.21   727.25
# Bowrider,Cabin Boat,Deck Boat                  2016     8.30     2.96
# Bowrider,Center console boat,Sport Boat        2018     6.81     2.36
# Bowrider,Classic                               1971     5.79     2.20
# Bowrider,Deck Boat,Water ski                   1995     6.14     2.47
# ...                                             ...      ...      ...
# Trawler                                     1316606  8891.86  2632.59
# Wakeboard/Wakesurf                           110848   395.29   141.42
# ...

# %%
df.groupby(['Boat Type']).agg({'Length': ['mean', 'max','min','sum'] })
# Out:
#                                             Length
#                                               mean    max   min      sum
# Boat Type
# Bowrider                                  6.504033  11.60  2.36  1951.21
# Bowrider,Cabin Boat,Deck Boat             8.300000   8.30  8.30     8.30
# Bowrider,Center console boat,Sport Boat   6.810000   6.81  6.81     6.81
# Bowrider,Classic                          5.790000   5.79  5.79     5.79
# Bowrider,Deck Boat,Water ski              6.140000   6.14  6.14     6.14
# ...                                            ...    ...   ...      ...
# Trawler                                  13.095523  46.40  5.70  8891.86
# Wakeboard/Wakesurf                        6.934912   8.31  5.90   395.29
# Wakeboard/Wakesurf,Water ski              6.350000   6.60  6.10    12.70
# Water ski                                 5.637778   6.67  2.32    50.74
# Working Boat                             13.862727  67.04  3.64   609.96
#
# [126 rows x 4 columns]
