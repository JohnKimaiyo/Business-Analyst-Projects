# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jki\Desktop\Preactse Data sets\salaries.csv")

# %%
df
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               SE              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 7969       2020               SE              FT
# 7970       2021               MI              FT
# 7971       2020               EN              FT
# 7972       2020               EN              CT
# 7973       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0     Business Intelligence Engineer   202800             USD         202800
# 1     Business Intelligence Engineer   104300             USD         104300
# 2                       Data Manager    60000             GBP          73824
# 3                       Data Manager    55000             GBP          67672
# 4                     Data Scientist   290000             USD         290000
# ...                              ...      ...             ...            ...
# 7969                  Data Scientist   412000             USD         412000
# 7970        Principal Data Scientist   151000             USD         151000
# 7971                  Data Scientist   105000             USD         105000
# 7972           Business Data Analyst   100000             USD         100000
# 7973            Data Science Manager  7000000             INR          94665
#
#      employee_residence  remote_ratio company_location company_size
# 0                    US             0               US            L
# 1                    US             0               US            L
# 2                    GB             0               GB            M
# 3                    GB             0               GB            M
# 4                    US             0               US            M
# ...                 ...           ...              ...          ...
# 7969                 US           100               US            L
# 7970                 US           100               US            L
# 7971                 US           100               US            S
# 7972                 US           100               US            L
# 7973                 IN            50               IN            L
#
# [7974 rows x 11 columns]

# %%
# display the last 10 rows of the dataset
df.head(10)
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2023               SE              FT  Business Intelligence Engineer
# 1       2023               SE              FT  Business Intelligence Engineer
# 2       2023               MI              FT                    Data Manager
# 3       2023               MI              FT                    Data Manager
# 4       2023               SE              FT                  Data Scientist
# 5       2023               SE              FT                  Data Scientist
# 6       2023               SE              FT                  Data Scientist
# 7       2023               SE              FT                  Data Scientist
# 8       2023               SE              FT      Machine Learning Scientist
# 9       2023               SE              FT      Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202800             USD         202800                 US             0
# 1  104300             USD         104300                 US             0
# 2   60000             GBP          73824                 GB             0
# 3   55000             GBP          67672                 GB             0
# 4  290000             USD         290000                 US             0
# 5  173200             USD         173200                 US             0
# 6  235000             USD         235000                 US           100
# 7  204000             USD         204000                 US           100
# 8  300000             USD         300000                 US             0
# 9  222000             USD         222000                 US             0
#
#   company_location company_size
# 0               US            L
# 1               US            L
# 2               GB            M
# 3               GB            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M
# 8               US            M
# 9               US            M

# %%
# find the last ten rows
df.tail(5)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 7969       2020               SE              FT            Data Scientist
# 7970       2021               MI              FT  Principal Data Scientist
# 7971       2020               EN              FT            Data Scientist
# 7972       2020               EN              CT     Business Data Analyst
# 7973       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 7969   412000             USD         412000                 US           100
# 7970   151000             USD         151000                 US           100
# 7971   105000             USD         105000                 US           100
# 7972   100000             USD         100000                 US           100
# 7973  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 7969               US            L
# 7970               US            L
# 7971               US            S
# 7972               US            L
# 7973               IN            L

# %%
# Find Shape of our Dataset (number of rows and columns)
data.shape
# Out:
# (148654, 13)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 148654
# Number of Columns 13

# %%
# Total number of columns,Datatypes of each column and memory requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB
